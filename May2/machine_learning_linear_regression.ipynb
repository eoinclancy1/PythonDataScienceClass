# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import load_boston

# %%
boston = load_boston()

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR'])

# %%
print(boston.DESCR)
# Out:
# Boston House Prices dataset
# ...
#
# Notes
# ------
# Data Set Characteristics:
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive
#
#     :Median Value (attribute 14) is usually the target
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
# ...

# %%
boston_df = pd.DataFrame(boston.data, columns=boston.feature_names)

# %%
boston_df['target']=boston.target

# %%
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %%
boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null float64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null float64
# TAX        506 non-null float64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# target     506 non-null float64
# dtypes: float64(14)
# memory usage: 55.4 KB

# %%
sns.pairplot(boston_df)

# %%
sns.distplot(boston_df.target)

# %%
sns.distplot(boston_df.LSTAT)

# %%
figure, axes = plt.subplots(figsize = (14,6))

plt.scatter(boston_df.LSTAT,boston_df.target)

# %%
sns.regplot(x=boston_df['LSTAT'],y=boston_df['target'])

# %%
sns.regplot(x=boston_df['CRIM'],y=boston_df['target'])

# %%
figure, axes = plt.subplots(figsize=(14,6))

plt.scatter(boston_df['DIS'],boston_df['CRIM'])

# %%
figure, axes = plt.subplots(figsize=(14,6))

plt.scatter(boston_df['DIS'],boston_df['target'])

# %%
boston_df.groupby('CHAS').target.mean()
# Out:
# CHAS
# 0.0    22.093843
# 1.0    28.440000
# Name: target, dtype: float64

# %%
figure, axes = plt.subplots(figsize=(12,6))

sns.boxplot(x=boston_df.CHAS,y=boston_df.target,data=boston_df)

# %%
figure, axes = plt.subplots(figsize=(14,6))

plt.scatter(boston_df.B,boston_df.target)

# %%
figure, axes = plt.subplots(figsize=(14,6))

plt.scatter(boston_df.B,boston_df.LSTAT)

# %%
figure, axes = plt.subplots(figsize=(14,6))

plt.scatter(boston_df.B,boston_df.DIS)

# %%
figure, axes = plt.subplots(figsize=(14,6))

sns.regplot(boston_df.RM,boston_df.target)

# %%
figure, axes = plt.subplots(figsize=(14,6))

plt.hist(boston_df.B)
# Out:
# (array([  18.,    6.,   10.,    2.,    3.,    3.,    7.,   11.,   33.,  413.]),
#  array([  3.20000000e-01,   3.99780000e+01,   7.96360000e+01,
#           1.19294000e+02,   1.58952000e+02,   1.98610000e+02,
#           2.38268000e+02,   2.77926000e+02,   3.17584000e+02,
#           3.57242000e+02,   3.96900000e+02]),
#  <a list of 10 Patch objects>)

# %%
figure, axes = plt.subplots(figsize=(14,6))

plt.hist(boston_df.NOX)
# Out:
# (array([ 75.,  80.,  89.,  60.,  78.,  30.,  57.,  21.,   0.,  16.]),
#  array([ 0.385 ,  0.4336,  0.4822,  0.5308,  0.5794,  0.628 ,  0.6766,
#          0.7252,  0.7738,  0.8224,  0.871 ]),
#  <a list of 10 Patch objects>)

# %%
figure, axes = plt.subplots(figsize=(14,6))

plt.scatter(boston_df.NOX,boston_df.target)

# %%
figure, axes = plt.subplots(figsize = (14,6))

sns.distplot(boston_df.target)

# %%
boston_df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.199458  0.404471 -0.055295  0.417521 -0.219940  0.350784
# ZN      -0.199458  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.404471 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055295 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.417521 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219940  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.350784 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.377904  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.622029 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.579564 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.288250 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
boston_df.target.corr(boston_df.LSTAT)
# Out:
# -0.73766272617401474

# %%
boston_df.corr().style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_c71df31e_4e50_11e8_b78f_dc5360f505b3row0_col0 {
#             background-color:  #b40426;
#         }    #T_c71df31e_4e50_11e8_b78f_dc5360f505b3row0_col1 {
#             background-color:  #6485ec;
#         }    #T_c71df31e_4e50_11e8_b78f_dc5360f505b3row0_col2 {
#             background-color:  #edd2c3;
#         }    #T_c71df31e_4e50_11e8_b78f_dc5360f505b3row0_col3 {
#             background-color:  #89acfd;
#         }    #T_c71df31e_4e50_11e8_b78f_dc5360f505b3row0_col4 {
#             background-color:  #efcfbf;
#         }    #T_c71df31e_4e50_11e8_b78f_dc5360f505b3row0_col5 {
#             background-color:  #5f7fe8;
#         }    #T_c71df31e_4e50_11e8_b78f_dc5360f505b3row0_col6 {
#             background-color:  #e5d8d1;
#         }    #T_c71df31e_4e50_11e8_b78f_dc5360f505b3row0_col7 {
#             background-color:  #3c4ec2;
#         }    #T_c71df31e_4e50_11e8_b78f_dc5360f505b3row0_col8 {
#             background-color:  #f6a283;
# ...

# %%
X=boston_df.drop('target',axis=1)

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
y=boston_df['target']

# %%
y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: target, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
#hint:  if you type train_test_split() and hold shift-tab inside the (), it will pop up help where you can copy the below
#This splits the data into training and testing data.  You can set test_size to what you want.  
#random_state is for reproducability
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=75)

# %%
print(len(X_train))
print(len(X_test))
print(len(y_train))
print(len(y_test))
# Out:
# 354
# 152
# 354
# 152

# %%
from sklearn.linear_model import LinearRegression

# %%
#instantiate an instance of the model
lm = LinearRegression()

# %%
#fit the model to the training data
#note that this happens in place on instance lm created above so no need to assign to a different variable
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print("Model intercept:", lm.intercept_)
# Out:
# Model intercept: 34.9541372252

# %%
lm.coef_
# Out:
# array([ -1.34474197e-01,   3.90986088e-02,   2.66331099e-02,
#          3.79005344e+00,  -1.76547919e+01,   3.78771137e+00,
#         -9.38428731e-03,  -1.52308695e+00,   3.02125808e-01,
#         -7.94221152e-03,  -8.65586638e-01,   9.21783072e-03,
#         -5.80731856e-01])

# %%
cdf = pd.DataFrame(lm.coef_,X_train.columns,columns=['Coeff'])

# %%
cdf
# Out:
#              Coeff
# CRIM     -0.134474
# ZN        0.039099
# INDUS     0.026633
# CHAS      3.790053
# NOX     -17.654792
# RM        3.787711
# AGE      -0.009384
# DIS      -1.523087
# RAD       0.302126
# TAX      -0.007942
# PTRATIO  -0.865587
# B         0.009218
# LSTAT    -0.580732

# %% [markdown]
# ### Predictions

# %%
predictions = lm.predict(X_test)

# %%
predictions[0:10]
# Out:
# array([ 34.07230409,  22.46863856,  21.74824214,  28.65556971,
#         19.80813021,  15.44091237,  25.08308928,  18.87499407,
#         21.54464911,  19.29284591])

# %%
figure, axes = plt.subplots(figsize=(14,6))

plt.scatter(y_test,predictions)
#plt.plot(X_test,predictions)

# %%
sns.distplot((y_test-predictions))

# %%
figure, axes = plt.subplots(figsize=(14,6))

sns.regplot(predictions,y_test)

# %%
from sklearn import metrics

# %%
metrics.r2_score(y_test,predictions)
# Out:
# 0.75183142770046929

# %%
metrics.mean_absolute_error(y_test,predictions)
# Out:
# 3.4070022568343834

# %%
metrics.mean_squared_error(y_test,predictions)
# Out:
# 19.964963570666512

# %%
np.sqrt(metrics.mean_squared_error(y_test,predictions))
# Out:
# 4.4682170460561235

# %%
X_2 = boston_df.drop(['target','B','ZN','NOX'],axis=1)
y_2 = boston_df.target

# %%
X_2_train, X_2_test, y_2_train, y_2_test = train_test_split(X_2, y_2, test_size=0.3, random_state=75)

# %%
print(len(X_2_train))
print(len(X_2_test))
print(len(y_2_train))
print(len(y_2_test))
# Out:
# 354
# 152
# 354
# 152

# %%
lm_2 = LinearRegression()

# %%
lm_2.fit(X_2_train,y_2_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predict_2 = lm_2.predict(X_2_test)

# %%
figure, axes = plt.subplots(figsize=(14,6))

sns.regplot(predict_2,y_2_test)

# %%
metrics.mean_absolute_error(y_2_test,predict_2)
# Out:
# 3.6398094571584121

# %%
np.sqrt(metrics.mean_squared_error(y_2_test,predict_2))
# Out:
# 4.8383455109175175

# %%
X_3 = boston_df.drop(['target','RM','AGE','LSTAT','CRIM'],axis=1)
y_3 = boston_df.target

# %%
X_3_train, X_3_test, y_3_train, y_3_test = train_test_split(X_3, y_3, test_size=0.3, random_state=75)

# %%
lm_3 = LinearRegression()

# %%
lm_3.fit(X_3_train,y_3_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predict_3=lm_3.predict(X_3_test)

# %%
figure, axes = plt.subplots(figsize=(14,6))

sns.regplot(predict_3,y_3_test)

# %%
metrics.r2_score(y_3_test,predict_3)
# Out:
# 0.5189539384787144

# %%
metrics.mean_absolute_error(y_3_test,predict_3)
# Out:
# 4.8377162255026143

# %%
np.sqrt(metrics.mean_squared_error(y_3_test,predict_3))
# Out:
# 6.2209140575964454

# %%
figure, axes = plt.subplots(figsize=(14,6))

sns.regplot(y_test,predictions,label='Test1')
sns.regplot(y_2_test,predict_2,label='Test2')
sns.regplot(y_3_test,predict_3,label='Test3')
axes.legend()
